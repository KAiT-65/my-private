# %% [markdown]
# # Build APK for Kivy App using Google Colab
#
# Run all cells to build the APK. This will take 20-30 minutes.

# %%
# Install dependencies
# !apt-get update
# !apt-get install -y build-essential git python3 python3-pip openjdk-17-jdk
# !pip install --upgrade pip
# !pip install buildozer cython

# %%
# Create project directory
# !mkdir -p /content/instaling_app
# %cd /content/instaling_app

# %%
# Upload your files here (main.py, buildozer.spec)
# After running this cell, click the "Choose Files" button to upload
from google.colab import files
print("Upload main.py and buildozer.spec")
uploaded = files.upload()

# List uploaded files
# !ls -la

# %%
# Build APK (this willtake 20-30 minutes)
# !buildozer android debug

# %%
# Download the APK
from google.colab import files
files.download('/content/instaling_app/bin/*.apk')
